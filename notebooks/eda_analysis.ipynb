# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# %%
sys.path.append(os.path.abspath('../scripts'))

# %%
from eda_analysis import (data_summary,plot_numerical_distribution,plot_categorical_distribution,plot_correlation_matrix
                          ,missing_value_summary,detect_outliers)

# %%
data=pd.read_csv('../data/data.csv')
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
summary = data_summary(data)
print(summary)
# Out:
# {'shape': (95662, 16)}

# %%
plot_numerical_distribution(data)

# %%
plot_categorical_distribution(data, categorical_columns=['CurrencyCode', 'CountryCode'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_categorical_distribution(data, categorical_columns=['CurrencyCode', 'CountryCode'])
#
# TypeError: plot_categorical_distribution() got an unexpected keyword argument 'categorical_columns'

# %%
plot_correlation_matrix(data, numerical_columns=['Amount', 'Value'])

# %%
print(missing_value_summary(data))
# Out:
# Series([], dtype: int64)

# %%
detect_outliers(data, numerical_columns=['Amount', 'Value'])
